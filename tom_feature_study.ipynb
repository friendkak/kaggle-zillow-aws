# %%
import pandas as pd
import numpy as np

# %%
train2017 = pd.read_csv('s3://zillow-kaggle-awsml-2020/train_2017.csv')

# %%
train2016 = pd.read_csv('s3://zillow-kaggle-awsml-2020/train_2016_v2.csv')

# %%
train2017
# Out:
#        parcelid  logerror transactiondate
# 0      14297519  0.025595      2017-01-01
# 1      17052889  0.055619      2017-01-01
# 2      14186244  0.005383      2017-01-01
# 3      12177905 -0.103410      2017-01-01
# 4      10887214  0.006940      2017-01-01
# 5      17143294 -0.020526      2017-01-01
# 6      12095076 -0.001011      2017-01-01
# 7      12069064  0.101723      2017-01-01
# 8      12790562 -0.040966      2017-01-02
# 9      11542646 -0.036763      2017-01-02
# 10     11104527  0.005963      2017-01-02
# 11     13984101 -0.147997      2017-01-02
# 12     14705431 -0.028835      2017-01-02
# 13     13944538  0.045602      2017-01-02
# 14     14731691 -0.008935      2017-01-02
# 15     17110996  0.008669      2017-01-02
# 16     14375300 -0.021896      2017-01-02
# 17     12045625 -0.017167      2017-01-02
# 18     11830315 -0.035085      2017-01-02
# 19     14730402 -0.012041      2017-01-02
# 20     12325145  0.042463      2017-01-02
# ...

# %%
properties2016 = pd.read_csv('s3://zillow-kaggle-awsml-2020/properties_2016.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
properties2016
# Out:
#           parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0         10754147                    NaN                       NaN
# 1         10759547                    NaN                       NaN
# 2         10843547                    NaN                       NaN
# 3         10859147                    NaN                       NaN
# 4         10879947                    NaN                       NaN
# 5         10898347                    NaN                       NaN
# 6         10933547                    NaN                       NaN
# 7         10940747                    NaN                       NaN
# 8         10954547                    NaN                       NaN
# 9         10976347                    NaN                       NaN
# 10        11073947                    NaN                       NaN
# 11        11114347                    NaN                       NaN
# 12        11116947                    NaN                       NaN
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
properties2016.columns.shape
# Out:
# (58,)

# %%
properties2016.hist(figsize=(40,500), layout=(58,1))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2e1a011630>],
# ...
#       dtype=object)

# %%
properties2016.columns.values
# Out:
# array(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13',
#        'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude',
#        'lotsizesquarefeet', 'poolcnt', 'poolsizesum', 'pooltypeid10',
#        'pooltypeid2', 'pooltypeid7', 'propertycountylandusecode',
#        'propertylandusetypeid', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'storytypeid',
# ...

# %%
properties2016[(~properties2016['lotsizesquarefeet'].isna()) & (properties2016['lotsizesquarefeet'] < 90000)]['lotsizesquarefeet'].hist()

# %%
properties2016[(~properties2016['landtaxvaluedollarcnt'].isna()) &  (properties2016['landtaxvaluedollarcnt'] < 100000)]['landtaxvaluedollarcnt'].hist()

# %%
def show_not_na(df, column):
    return df.loc[~df[column].isna(), column]

# %%
show_not_na(properties2016,'buildingqualitytypeid').hist()

# %%
import seaborn as sns

# %%
temp_data = properties2016[(~properties2016['structuretaxvaluedollarcnt'].isna()) & (~properties2016['buildingqualitytypeid'].isna()) & (~properties2016['finishedsquarefeet12'].isna()) & (properties2016['finishedsquarefeet12']>600) & (properties2016['structuretaxvaluedollarcnt'] < 2000000)]
sns.stripplot(temp_data['buildingqualitytypeid'], temp_data['structuretaxvaluedollarcnt']/temp_data['finishedsquarefeet12'], jitter=.33)

# %%
temp_data[(temp_data['structuretaxvaluedollarcnt']/temp_data['finishedsquarefeet12'] > 2000)]
# Out:
#          parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 1178847  11547694                    NaN                       NaN
# 1359185  12022440                    1.0                       NaN
# 1848920  11690414                    1.0                       NaN
# 2281432  12134047                    1.0                       NaN
# 2532269  11669860                    1.0                       NaN
# 2591520  11641875                    NaN                       NaN
# 2948718  11656332                    1.0                       NaN
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 1178847           NaN          1.0         3.0                  NaN
# 1359185           NaN          2.0         3.0                  NaN
# 1848920           NaN          4.0         4.0                  NaN
# 2281432           NaN          2.0         4.0                  NaN
# 2532269           NaN          7.0         6.0                  NaN
# ...

# %%
properties2016[properties2016['taxvaluedollarcnt'] > 70000000]
# Out:
#          parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 104030   11784354                   13.0                       NaN
# 341893   11746970                   13.0                       NaN
# 446201   11525377                    NaN                       NaN
# 460997   12560578                    NaN                       NaN
# 550147   11525384                    NaN                       NaN
# 609555   11783588                    NaN                       NaN
# 639369   11622590                   13.0                       NaN
# 728267   11635852                    NaN                       NaN
# 733210   11642367                    1.0                       NaN
# 1100460  11638221                    NaN                       NaN
# 1130185  10806423                    NaN                       NaN
# 1130220  11591023                   13.0                       NaN
# 1130227  11638223                    NaN                       NaN
# ...

# %%
log_transform_vars = ['bathroomcnt', 'bedroomcnt', ]

# %%
cat_vars = ['air_coded', ]

# %%
def code_data(data):
    rdata['air_coded'] = data['airconditioningtypeid'].map(lambda v: 'one' if v==1 (else 'na' if pd.isna(v) else 'other'))
    rdata['bathroom_overage'] = data['bathroomcnt'].map(lambda v: np.max(v-4,0))
    rdata['knockdown'] = data.apply(lambda row: 1 if row['landtaxvaluedollarcnt']>20000 and row['structuretaxvaluedollarcnt'] >20000 and row['structuretaxvaluedollarcnt'] < row['landtxvaluedollarcnt'] else 0, axis='columns')
    rdata['vacantlot'] = data.apply(lambda row: 1 if row['structuretaxvaluedollarcnt'] < 30000 and row['landtaxvaluedollarcnt'] > 20000 else 0, axis='columns')
    rdata['low_qual_building'] = data['buildingqualitytypeid'].map(lambda v: 1 if v in [2,3,5,6,8,9,11])
    rdata['med_qual_building'] = data['buildingqualitytypeid'].map(lambda v: 1 if v in [12])
    rdata['assessed_structure_cost_per_sqft_outlier'] = data.apply(lambda row: 1 if row['finishedsquarefeet12']>600 and row['structurevaluedollarcnt']<2000000 and row['structure_valuedollarcnt']/row['finishedsquarefoot12] > 800'], axis='columns')
    rdata['topmarket'] = data[]

# %%
#exclude lot size greater than 2 acres
#code a flag variable for lot size greater than 20k ftsq

# %%
pd.isna(None)
# Out:
# True
